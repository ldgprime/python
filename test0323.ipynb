# %%
from selenium import webdriver
driver=webdriver.Chrome("chromedriver")
#river=webdriver.PhantomJS('phantomjs')
driver.implicitly_wait(3)
driver.get("https://movie.naver.com/movie/running/current.nhn")
#tag=driver.find_elements_by_tag_name('div')
li=driver.find_elements_by_css_selector('ul.lst_detail_t1 > li')
print(li)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="c1ab266d-1abd-4bb1-8aeb-5391214119f4")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="defb0b1f-f452-495f-a21c-dec0ffb514b2")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="1bd85c71-5f91-4d60-94aa-a8758cef566e")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="1fa70503-df3c-4b71-94b8-af2bed36afcc")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="6f84ce3b-25d8-4ce9-8d69-13d0893ea46e")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="330c88e5-e630-4778-b8e1-7e7b5db97222")>, <selenium.webdriver.remote.webelement.WebElement (session="2e53cf7774a0b212f059e7d4cf71dd7f", element="ffd5e6f5-3c65-484c-822c-7ffd23
# ...

# %%
from selenium import webdriver
driver=webdriver.Chrome("chromedriver")
#river=webdriver.PhantomJS('phantomjs')
driver.implicitly_wait(3)

# %%
driver.get('https://nid.naver.com/nidlogin.login')
driver.find_element_by_name('id').send_keys('miya_2009')
driver.find_element_by_name('pw').send_keys('rud290')
driver.find_element_by_xpath("//*[@id='log.login']").click()

# %%
driver.get('https://naver.com')

# %%
from bs4 import BeautifulSoup
driver.get("https://order.pay.naver.com/home")
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')
notices=soup.select('div.goods_item > div > a.goods > p')

for n in notices:
    print(n.text)
# Out:
# 포인트플러스
# 							[2개구매 무료배송] 삼성 갤럭시노트10 플러스 갤럭시 S10 5G S9 S8 노트9 노트8 플러스 실리콘 케이스 아이폰 11 프로 맥스 XS XR X 아이폰8 아이폰7
#
#
# 포인트플러스
# 							비즈헤어피스 포인트머리핀 트윙클붙임머리
#
#
# 포인트플러스
# 							비즈헤어피스 포인트머리핀 트윙클붙임머리
#
#
# 포인트플러스
# 							비즈헤어피스 포인트머리핀 트윙클붙임머리
#
#
# 포인트플러스
# 							비즈헤어피스 포인트머리핀 트윙클붙임머리
#
#
# 포인트플러스
# 							비즈헤어피스 포인트머리핀 트윙클붙임머리
#
#
# 							배트맨/베트맨 아캄나이트 27CM 피규어 프레이아츠
#
#
# 							인스 스티커 랜덤박스 1+1

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
plt.plot([1,2,3,5],[1,2,4,6],'v-',[1,2,3,4],[1,2,3,4],'r-')
plt.show()
