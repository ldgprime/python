# %%
import pandas as pd

# %%
df=pd.read_csv('data/cctv/부산광역시_부산진구_어린이보호구역_CCTV_20190917.csv',encoding='utf-8')
df
# Out:
#           관리기관명                 소재지도로명주소                소재지지번주소 설치목적구분  카메라대수  \
# 0   부산광역시 부산진구청       부산광역시 부산진구 성지로 116   부산광역시 부산진구 초읍동 178-6  어린이보호      1
# 1   부산광역시 부산진구청    부산광역시 부산진구 안창로14번길 78    부산광역시 부산진구 범천동 1536  어린이보호      0
# 2   부산광역시 부산진구청  부산광역시 부산진구 백양대로260번길 16   부산광역시 부산진구 개금동 419-3  어린이보호      0
# 3   부산광역시 부산진구청    부산광역시 부산진구 양지로11번길 64   부산광역시 부산진구 양정동 345-2  어린이보호      1
# 4   부산광역시 부산진구청     부산광역시 부산진구 국악로60번길 4  부산광역시 부산진구 초읍동 616-15  어린이보호      0
# ..          ...                      ...                    ...    ...    ...
# 84  부산광역시 부산진구청  부산광역시 부산진구 진사로61번길 28-7   부산광역시 부산진구 개금동 630-5  어린이보호      1
# 85  부산광역시 부산진구청        부산광역시 부산진구 복지로 71  부산광역시 부산진구 개금동 565-14  어린이보호      0
# 86  부산광역시 부산진구청   부산광역시 부산진구 성지로104번길 26     부산광역시 부산진구 초읍동 540  어린이보호      1
# 87  부산광역시 부산진구청  부산광역시 부산진구 백양대로320번길 40  부산광역시 부산진구 개금동 446-14  어린이보호      1
# 88  부산광역시 부산진구청   부산광역시 부산진구 백양순환로 70-11   부산광역시 부산진구 당감동 775-2  어린이보호      1
#
# ...

# %%
# Python 샘플 코드 #



from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote, quote



url = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : 'WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D', quote_plus('YM') : '201201', quote_plus('NAT_CD') : '112', quote_plus('ED_CD') : 'D' })
print(url+queryParams)
request = Request(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?ServiceKey=WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%253D%253D&YM=201201&NAT_CD=112&ED_CD=D
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2020-03-18T16:14:58.391+09:00</responseTime><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'

# %%
# Python 샘플 코드 #



from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote



url = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList'
queryParams = '?' + urlencode({ quote_plus('ServiceKey') : unquote('WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D'), quote_plus('YM') : '201201', quote_plus('NAT_CD') : '112', quote_plus('ED_CD') : 'D' })
print(url+queryParams)
request = Request(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?ServiceKey=WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D&YM=201201&NAT_CD=112&ED_CD=D
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2020-03-18T16:14:48.969+09:00</responseTime><resultCode>22</resultCode><resultMsg>LIMITED NUMBER OF SERVICE REQUESTS EXCEEDS ERROR.</resultMsg></header></response>'

# %%
print('WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D')
print(quote('WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D'))
print(quote(unquote('WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D')))
# Out:
# WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D
# WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%253D%253D
# WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D

# %%
import os
import sys
import urllib.request 
import datetime 
import time 
import json 
from config import * 
import matplotlib.pyplot as plt 
import matplotlib 
from matplotlib import font_manager, rc

def get_request_url(url): 
    req = urllib.request.Request(url)

    try: 
        response = urllib.request.urlopen(req) 
        if response.getcode() == 200: 
#             print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8') 
    except Exception as e: 
        print(e) 
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url)) 
        return None

# %%
#[CODE 1] 
def getNatVisitor(yyyymm, nat_cd, ed_cd): 
    access_key= 'WFNvw1hDGvgw8dy6Ro8c2U21oq8zNqi1KFewLzAfVOYhdv8qLoRTTMWl2RPwzcxpf2vMkksMlGe6FoMMKrotXA%3D%3D'
    end_point = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    parameters = "?_type=json&serviceKey=" + access_key
    parameters += "&YM=" + yyyymm 
    parameters += "&NAT_CD=" + nat_cd 
    parameters += "&ED_CD=" + ed_cd

    url = end_point + parameters
    retData = get_request_url(url)
    if (retData == None): 
        return None 
    else: 
        return json.loads(retData)

# %%
 def draw_chart(jsonResult):
    cnVisit = [] 
    VisitYM = [] 
    index = [] 
    i = 0 
    
    for item in jsonResult: 
        index.append(i) 
        cnVisit.append(item['visit_cnt']) 
        VisitYM.append(item['yyyymm']) 
        i = i + 1
        print(VisitYM)
    #[CODE 2] 
    font_location = "c:/Windows/fonts/malgun.ttf" 
    font_name = font_manager.FontProperties(fname=font_location).get_name() 
    matplotlib.rc('font', family=font_name)
    plt.xticks(index, VisitYM) 
    plt.plot(index, cnVisit) 
    plt.xlabel('방문월')
    plt.ylabel('방문객수') 
    plt.grid(True) 
    plt.show()

# %%
def mysql_save(jsonResult):
    try:
        conn=pymysql.connect(host='localhost',user='ldg',password='1234',db='ldg',charset='utf8')
        cursor=conn.cursor()
        sql='''insert into to_visit(nat_name,yyyymm,totalvistit) values(%s,%s,%s)
        '''
        items=[]
        for row in jsonResult:
            t=(row['nat_name'],row['visit_cnt'],row['yyyymm'])
            items.append(t)
        cursor.executemany(sql,items)
        conn.commit()
    except Exception as e:
        print(e)
        print('db error')
    finally:
        conn.close()

# %%
def main(): 
    jsonResult = [] 
    #중국: 112 / 일본: 130 / 미국: 275 
    national_code = "112"
    ed_cd = "E"

    nStartYear = 2011 
    nEndYear = 2020

    for year in range(nStartYear, nEndYear):
        for month in range(1, 13): 
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
#             print(yyyymm)
            jsonData = getNatVisitor(yyyymm, national_code, ed_cd)
        
#             print (json.dumps(jsonData,indent=4, sort_keys=True,ensure_ascii=False))
        
        if (jsonData['response']['header']['resultMsg'] == 'OK'): 
            krName = jsonData['response']['body']['items']['item']["natKorNm"] 
            krName = krName.replace(' ', '')
            iTotalVisit = jsonData['response']['body']['items']['item']["num"] 
#             print('%s_%s : %s' %(krName, yyyymm, iTotalVisit))
            jsonResult.append({'nat_name': krName, 'nat_cd': national_code, 'yyyymm': yyyymm, 'visit_cnt': iTotalVisit})
            

    print(krName)
    with open('data/%s(%s)_해외방문객정보_%d_%d.json' % (krName, national_code, nStartYear, nEndYear-1), 'w', encoding='utf8') as outfile: 
        retJson = json.dumps(jsonResult,indent=4, sort_keys=True, ensure_ascii=False) 
        outfile.write(retJson)
    
    draw_chart(jsonResult)

# %%
if __name__ == '__main__': 
    main()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-13-8297ee659976> in <module>
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-12-3cafa517124b> in main()
#      24
#      25
# ---> 26     print(krName)
#      27     with open('data/%s(%s)_해외방문객정보_%d_%d.json' % (krName, national_code, nStartYear, nEndYear-1), 'w', encoding='utf8') as outfile:
#      28         retJson = json.dumps(jsonResult,indent=4, sort_keys=True, ensure_ascii=False)
#
# UnboundLocalError: local variable 'krName' referenced before assignment

# %%
for x in range(1, 11):
    print('{0:2d} {1:3d} {2:4d}'.format(x, x*x, x*x*x))
