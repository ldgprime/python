# %%
def calculate_ractangle_area(x,y):
    return x*y

# %%
x=10
y=20
print('사각형 x의 길이:',x)
print('사각형 y의 길이:',y)
print('사각형의 넓이:',calculate_ractangle_area(x,y))

# %%
#call by value
def f(x):
    y=x
    x=5
    return x*y

# %%
x=3
print(f(x))
print(x)
# Out:
# 15
# 3

# %%
#call by reference
def spam(agg):
    agg.append(1)
    agg.append(2) #레퍼런스에 의한 것
    
    agg=[4,5,6] #함수안에서 별도로 만든 것, 새로운 객체 생성
    agg.append(1)
    agg.append(2)
    
    
    print("함수:",agg)

# %%
ham=[0]
spam(ham)
print(ham)
# Out:
# 함수: [4, 5, 6, 1, 2]
# [0, 1, 2]

# %%
def test(t):
    print(x)
    t=20
    print("In Function:", t)

x=10
test(x)
print("In Main:", x)
print("In Main:", t)
# Out:
# 10
# In Function: 20
# In Main: 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c6a01264d74e> in <module>
#       7 test(x)
#       8 print("In Main:", x)
# ----> 9 print("In Main:", t)
#
# NameError: name 't' is not defined

# %%
def f():  #가까운 것 부터 사용한다.
    s = "I love Londen!"
    print(s)

s="I love Paris!"
f()
print(s)
# Out:
# I love Londen!
# I love Paris!

# %%
def f():
    global s
   #s ="I love Paris!" 
    s = "I love Londen!"
   #s = "I love Londen!"
    print(s)

s="I love Paris!"
#s ="I love Paris!" 
f()
#s = "I love Londen!"
print(s)
# Out:
# I love Londen!
# I love Londen!

# %%
def factorial(n):
    if n==1:
        return 1
    else:
        return n*factorial(n-1)

# %%
num = int(input("숫자입력: "))
print(factorial(num))
# Out:
# 숫자입력: 10
# 3628800

# %%
def sum(x,y=1): 
    return x+y

# %%
def sum2(x=1,y): #디폴트변수를 앞에다 주지 않는다.
    return x+y
# Out:
#   File "<ipython-input-34-b506545a6f43>", line 1
#     def sum2(x=1,y):
#             ^
# SyntaxError: non-default argument follows default argument

# %%
print(sum(10))
print(sum(10,5))
# Out:
# 11
# 15

# %%
list=[1,2,3,4]
a,b,*c=list
print(a,b,c)
# Out:
# 1 2 [3, 4]

# %%
def sum3(x,y,*z): #tuple
    print(x,y,*z)

# %%
sum3(10,1,1)
sum3(10,5,1,1,1,2)
# Out:
# 10 1 1
# 10 5 1 1 1 2

# %%
def kwargs_test(**kwargs):
    print(kwargs) #딕셔너리형
    print("First value is {first}".format(**kwargs))
    print("{first} and {second},{third}".format(**kwargs))
    
kwargs_test(first=1, second=2, third=3)
# Out:
# {'first': 1, 'second': 2, 'third': 3}
# First value is 1
# 1 and 2,3

# %%
a='python'
a[0:-1]
# Out:
# 'pytho'

# %% [markdown]
# # a*2

# %%
a*2
# Out:
# 'pythonpython'

# %%
print('p' in a)
# Out:
# True

# %%
if 'o' in a:
    print('있습니다')
else:
    print('없습니다')
# Out:
# 있습니다

# %%
a+str(3.7)
# Out:
# 'python3.7'
